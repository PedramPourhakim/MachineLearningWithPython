# %% [markdown]
# ## pip install matplotlib

# %% [markdown]
# ### Math Plot Library

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
#  سلول پایینی اگر احیانا سیستم نتونست نمودار بکشه و گرنه نیازی به نوشتنش نیست

# %%
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
plt.plot([1,2,3,4])
plt.ylabel('funny numbers')
plt.show() #این برای خارج از محیط جوپیتر نوتبوکه و اینجا نیاز به نوشتنش نیست

# %%
plt.plot([1,3,4,9], [-1,8,1,2])

# %%
plt.plot([1,3,4,9],[-1,8,1,2],'ro') #r means red, o means dot

# %%
t = np.arange(0, 5 , 0.2)
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
plt.plot(t,t * 2)

# %%
plt.plot(t , t, 'r-.' , t, t **2, 'bs',t, t ** 3, 'g^')

# %%
data = {
    'a' : np.arange(500), #از صفر  تا 49 برام منظم بشمر
    'b' : np.random.randint(0 , 50 , 50), #پنجاه تا عدد رندوم صحیح میخوام در بازه ی صفر تا پنجاه
    'c' : np.random.randn(500) # پنجاه تا عدد به صورت توزیع نرمال بده
}

# %%
plt.scatter(data['a'],data['c'])
