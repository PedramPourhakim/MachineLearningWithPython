# %% [markdown]
# ### Non-Linear Regression

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(- 5.0 , 5.0 , 0.1)
y = 2 * (x) + 3

y_noise = 2 * np.random.normal(size = x.size)

ydata = y + y_noise

plt.plot(x , ydata , 'bo')
plt.plot(x,y , 'r')

plt.ylabel('Dependant Variable')
plt.xlabel('Independant Variable')
plt.show()

# %%
x = np.arange(-5.0,5.0,0.1)
y = 1 * (x ** 3) + 1 * (x ** 2) + 1 * x + 3
y_noise = 20 * np.random.normal(size = x.size)
ydata =  y + y_noise
plt.plot(x, ydata, 'bo')
plt.plot(x, y, 'r')
plt.ylabel('Dependent variable')
plt.xlabel('Indepedent variable')
plt.show()

# %% [markdown]
# Y = x ** 2

# %%
x = np.arange(-5.0,5.0,0.1)

y = np.power(x , 2)

y_noise = 2 * np.random.normal(size = x.size)

ydata = y + y_noise

plt.plot(x,ydata,'bo')

plt.plot(x, y , 'r')

plt.ylabel('Dependent Variable')

plt.xlabel('Independent Variable')

plt.show()

# %% [markdown]
# ### Exponential : Y = a + bc ** x
# Y = Θ0 + Θ1 a ²

# %%
X = np.arange(-5.0,5.0,0.1)
Y = np.exp(X)

plt.plot(X,Y)
plt.ylabel('Dependent Variable')

plt.xlabel('Independent Variable')

plt.show()

# %% [markdown]
# ## Logarithmic : مثل قد کشیدن آدمها

# %%
X = np.arange(-5.0,5.0,0.1)
Y = np.log(X)

plt.plot(X,Y)
plt.ylabel('Dependent Variable')

plt.xlabel('Independent Variable')

plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19232\3501639911.py:2: RuntimeWarning: invalid value encountered in log
#   Y = np.log(X)

# %% [markdown]
# ### Sigmoidal/Logistic
#
# ### Y = (a + b) / (1 + c ** (x -d))

# %%
X = np.arange(-5.0,5.0,0.1)

Y = 1 - 4 / (1 + np.power(3 , X -2))

plt.plot(X,Y)
plt.ylabel('Dependent Variable')

plt.xlabel('Independent Variable')

plt.show()

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./china_gdp.csv')
# GDP means gross domestic product تولید ناخالص داخلی
df.tail(10)
# Out:
#     Year         Value
# 45  2005  2.268599e+12
# 46  2006  2.729784e+12
# 47  2007  3.523094e+12
# 48  2008  4.558431e+12
# 49  2009  5.059420e+12
# 50  2010  6.039659e+12
# 51  2011  7.492432e+12
# 52  2012  8.461623e+12
# 53  2013  9.490603e+12
# 54  2014  1.035483e+13

# %% [markdown]
# ### Plotting the data set

# %%
plt.figure(figsize=(8,5))
x_data , y_data = (df["Year"].values , df["Value"].values)
plt.plot(x_data,y_data,'ro')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
X = np.arange(-5.0,5.0,0.1)
Y = 1.0 / (1.0 + np.exp(-X))

plt.plot(X,Y)
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %%
def sigmoid(x, Beta_1, Beta_2):
    y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
    return y

# %%
beta_1 = 0.8
beta_2 = 2000.0

Y_pred = sigmoid(x_data,beta_1,beta_2)

plt.plot(x_data, Y_pred*15000000000000.0)
plt.plot(x_data,y_data,'ro')

# %%
# Lets Normalize our data (تبدیل عدد ها به بازه ی صفر تا یک)
xdata = x_data / max(x_data)
ydata = y_data / max(y_data)

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid,xdata,ydata)
# print the final parameters
print(" beta_1 = %f, beta_2 = %f" % (popt[0],popt[1]))
# Out:
#  beta_1 = 690.451711, beta_2 = 0.997207

# %%
x = np.linspace(1960,2015,55)
x = x/max(x)
plt.figure(figsize=(8,5))
y = sigmoid(x, *popt)
plt.plot(xdata,ydata,'ro',label='data')
plt.plot(x,y,linewidth = 3.0,label = 'fit')
plt.legend(loc = 'best')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()
print(sigmoid(2015,*popt))
# Out:
# 1.0

# %%
### Just For test
from scipy.optimize import curve_fit

def my_func(x,a,b):
    return a * x + b

my_func(1,2,3)

my_x = [1,2,3,4]
my_y = [5,7,9,11]

curve_fit(my_func,my_x,my_y)
my_y = [4,8,9,12]
curve_fit(my_func,my_x,my_y)
# Out:
# (array([2.5, 2. ]),
#  array([[ 0.15 , -0.375],
#         [-0.375,  1.125]]))
